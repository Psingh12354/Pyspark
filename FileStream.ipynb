# %%
import pyspark
from pyspark import SparkConf, SparkContext
from pyspark.streaming import StreamingContext

# %%
conf = SparkConf().setAppName("File streaming")
sc = SparkContext.getOrCreate(conf=conf)

# %%
# 10 sec streaming gap
ssc = StreamingContext(sc,10)

# %%
rdd = ssc.textFileStream("/FileStore/tables/")

# %%
rdd = rdd.map(lambda x: (x,1))
rdd = rdd.reduceByKey(lambda x,y: x+y)
rdd.pprint()

# %%
# 100000 second till
ssc.start()
ssc.awaitTerminationOrTimeout(100000)
# Out:
# -------------------------------------------
# Time: 2022-05-20 07:19:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:19:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:20:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:20:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:20:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:20:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:20:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:20:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:21:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:21:10
# -------------------------------------------
# ('My name is Priyanshu Singh it consist of first name Priyanshu which means first ray of light while the surname Singh which comes from the sanskrit word named simha it represent lions historically it is use by rajput. ', 1)
# ("For me there is no random best memory it is like the memory which makes me feel happy at the time of stressed is my best part of memory And same case with my bad experience for today which seems bad but it future if i recall it's look good. But one of the bad experience which I have is when I loose someone close to me.", 1)
# ("Now, talk about my hidden talent the first things which comes in my mind is my hidden talent is that's much perfectly hidden whom i am not able to discover. So, coming to the point what ever i do atleast know by 2 to 3 people so there is no hidden talent in me.", 1)
# ('Priyanshu Singh An Autobiography', 1)
#
# -------------------------------------------
# Time: 2022-05-20 07:21:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:21:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:21:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:21:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:22:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:22:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:22:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-05-20 07:22:30
# -------------------------------------------
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
